# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
import inflect
from word2number import w2n
import pickle
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv("./Data/CarPrice_Assignment.csv")

# %%
data.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# 25%    2145.000000   97.000000    3.150000    3.110000          8.600000
# 50%    2414.000000  120.000000    3.310000    3.290000          9.000000
# 75%    2935.000000  141.000000    3.580000    3.410000          9.400000
# max    4066.000000  326.000000    3.940000    4.170000         23.000000
#
#        horsepower      peakrpm     citympg  highwaympg         price
# count  205.000000   205.000000  205.000000  205.000000    205.000000
# mean   104.117073  5125.121951   25.219512   30.751220  13276.710571
# std     39.544167   476.985643    6.542142    6.886443   7988.852332
# min     48.000000  4150.000000   13.000000   16.000000   5118.000000
# 25%     70.000000  4800.000000   19.000000   25.000000   7788.000000
# 50%     95.000000  5200.000000   24.000000   30.000000  10295.000000
# 75%    116.000000  5500.000000   30.000000   34.000000  16503.000000
# max    288.000000  6600.000000   49.000000   54.000000  45400.000000

# %%
data.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %% [markdown]
# # a) Null and Missing Values

# %%
data.isna().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %% [markdown]
# # b) Feature Encoding (One-hot & Label Encoding)

# %%
np.unique(np.array(data['fuelsystem']) ) 
# one hot encoding: feultype, aspiration, engine_location
# label ecoding: carbody, enginetype, fuel system
# custom label encoding: doornumber, cylindernumber
# Out:
# array(['1bbl', '2bbl', '4bbl', 'idi', 'mfi', 'mpfi', 'spdi', 'spfi'],
#       dtype=object)

# %% [markdown]
# ## 1. One Hot Encoding for " FuelType" and "Aspiration"

# %%
encoded_data = pd.get_dummies(data, columns = ['fueltype', 'aspiration', 'enginelocation'])

# %%
encoded_data
# Out:
#      car_ID  symboling                   CarName doornumber      carbody  \
# 0         1          3        alfa-romero giulia        two  convertible
# 1         2          3       alfa-romero stelvio        two  convertible
# 2         3          1  alfa-romero Quadrifoglio        two    hatchback
# 3         4          2               audi 100 ls       four        sedan
# 4         5          2                audi 100ls       four        sedan
# ..      ...        ...                       ...        ...          ...
# 200     201         -1           volvo 145e (sw)       four        sedan
# 201     202         -1               volvo 144ea       four        sedan
# 202     203         -1               volvo 244dl       four        sedan
# 203     204         -1                 volvo 246       four        sedan
# 204     205         -1               volvo 264gl       four        sedan
#
#     drivewheel  wheelbase  carlength  carwidth  carheight  ...  peakrpm  \
# 0          rwd       88.6      168.8      64.1       48.8  ...     5000
# 1          rwd       88.6      168.8      64.1       48.8  ...     5000
# 2          rwd       94.5      171.2      65.5       52.4  ...     5000
# 3          fwd       99.8      176.6      66.2       54.3  ...     5500
# 4          4wd       99.4      176.6      66.4       54.3  ...     5500
# ..         ...        ...        ...       ...        ...  ...      ...
# 200        rwd      109.1      188.8      68.9       55.5  ...     5400
# 201        rwd      109.1      188.8      68.8       55.5  ...     5300
# 202        rwd      109.1      188.8      68.9       55.5  ...     5500
# 203        rwd      109.1      188.8      68.9       55.5  ...     4800
# 204        rwd      109.1      188.8      68.9       55.5  ...     5400
#
#     citympg highwaympg    price fueltype_diesel  fueltype_gas  aspiration_std  \
# 0        21         27  13495.0               0             1               1
# 1        21         27  16500.0               0             1               1
# 2        19         26  16500.0               0             1               1
# 3        24         30  13950.0               0             1               1
# 4        18         22  17450.0               0             1               1
# ..      ...        ...      ...             ...           ...             ...
# 200      23         28  16845.0               0             1               1
# 201      19         25  19045.0               0             1               0
# 202      18         23  21485.0               0             1               1
# 203      26         27  22470.0               1             0               0
# 204      19         25  22625.0               0             1               0
#
#      aspiration_turbo  enginelocation_front  enginelocation_rear
# 0                   0                     1                    0
# 1                   0                     1                    0
# 2                   0                     1                    0
# 3                   0                     1                    0
# 4                   0                     1                    0
# ..                ...                   ...                  ...
# 200                 0                     1                    0
# 201                 1                     1                    0
# 202                 0                     1                    0
# 203                 1                     1                    0
# 204                 1                     1                    0
#
# [205 rows x 29 columns]

# %% [markdown]
# #  2. Custom Encoder for "no of doors" and "no of cylinders"

# %%
# a = np.unique(np.array(hot_encoded_data['cylindernumber']))
# b = np.unique(np.array(hot_encoded_data['doornumber']))
# c= np.concatenate((a.reshape(1, -1), b.reshape(1, -1)), axis=1)
# c = np.unique(c)
# c

# # c2 = np.arange(1, 13)
# # p = inflect.engine()
# nums = np.array([(w2n.word_to_num(n), n) for n in list(c )])
# nums

# %%
def num_encoder(x):
    return w2n.word_to_num(x)


encoded_data['doornumber'] = encoded_data['doornumber'].map(lambda x: w2n.word_to_num(x))
encoded_data['cylindernumber'] = encoded_data['cylindernumber'].map(lambda x:w2n.word_to_num(x))

# %%
encoded_data['cylindernumber']
# Out:
# 0      4
# 1      4
# 2      6
# 3      4
# 4      5
#       ..
# 200    4
# 201    4
# 202    6
# 203    6
# 204    4
# Name: cylindernumber, Length: 205, dtype: int64

# %%
data['cylindernumber']
# Out:
# 0      four
# 1      four
# 2       six
# 3      four
# 4      five
#        ...
# 200    four
# 201    four
# 202     six
# 203     six
# 204    four
# Name: cylindernumber, Length: 205, dtype: object

# %%
with open('./hot_custom_encoded_data.pkl', 'wb') as f:
    pickle.dump(encoded_data, f)

# %% [markdown]
# # 3. Label Encoding for other columns

# %%
np.unique(np.array(data['carbody']))
# Out:
# array(['convertible', 'hardtop', 'hatchback', 'sedan', 'wagon'],
#       dtype=object)

# %%
lbl_enc = LabelEncoder()

# %%
encoded_data['carbody'] = lbl_enc.fit_transform(encoded_data['carbody'])

# %%
encoded_data['carbody']
# Out:
# 0      0
# 1      0
# 2      2
# 3      3
# 4      3
#       ..
# 200    3
# 201    3
# 202    3
# 203    3
# 204    3
# Name: carbody, Length: 205, dtype: int64

# %%
np.unique(np.array(data['enginetype']))
# Out:
# array(['dohc', 'dohcv', 'l', 'ohc', 'ohcf', 'ohcv', 'rotor'], dtype=object)

# %%
encoded_data['enginetype'] = lbl_enc.fit_transform(encoded_data['enginetype'])

encoded_data['enginetype']
# Out:
# 0      0
# 1      0
# 2      5
# 3      3
# 4      3
#       ..
# 200    3
# 201    3
# 202    5
# 203    3
# 204    3
# Name: enginetype, Length: 205, dtype: int64

# %%
np.unique(np.array(data['fuelsystem']))
# Out:
# array(['1bbl', '2bbl', '4bbl', 'idi', 'mfi', 'mpfi', 'spdi', 'spfi'],
#       dtype=object)

# %%
encoded_data['fuelsystem'] = lbl_enc.fit_transform(encoded_data['fuelsystem'])

encoded_data['fuelsystem']
# Out:
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5
#       ..
# 200    5
# 201    5
# 202    5
# 203    3
# 204    5
# Name: fuelsystem, Length: 205, dtype: int64

# %% [markdown]
# # c) Feature Normalization

# %%
# Selecting numeric features using info from data dictionary

# %%
numeric_features = ['wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight', 'enginesize', 'boreratio', 'stroke','compressionratio','horsepower','peakrpm','citympg','highwaympg']
num_data = encoded_data [numeric_features]
num_data
# Out:
#      wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# 0         88.6      168.8      64.1       48.8        2548         130
# 1         88.6      168.8      64.1       48.8        2548         130
# 2         94.5      171.2      65.5       52.4        2823         152
# 3         99.8      176.6      66.2       54.3        2337         109
# 4         99.4      176.6      66.4       54.3        2824         136
# ..         ...        ...       ...        ...         ...         ...
# 200      109.1      188.8      68.9       55.5        2952         141
# 201      109.1      188.8      68.8       55.5        3049         141
# 202      109.1      188.8      68.9       55.5        3012         173
# 203      109.1      188.8      68.9       55.5        3217         145
# 204      109.1      188.8      68.9       55.5        3062         141
#
#      boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0         3.47    2.68               9.0         111     5000       21
# 1         3.47    2.68               9.0         111     5000       21
# 2         2.68    3.47               9.0         154     5000       19
# 3         3.19    3.40              10.0         102     5500       24
# 4         3.19    3.40               8.0         115     5500       18
# ..         ...     ...               ...         ...      ...      ...
# 200       3.78    3.15               9.5         114     5400       23
# 201       3.78    3.15               8.7         160     5300       19
# 202       3.58    2.87               8.8         134     5500       18
# 203       3.01    3.40              23.0         106     4800       26
# 204       3.78    3.15               9.5         114     5400       19
#
#      highwaympg
# 0            27
# 1            27
# 2            26
# 3            30
# 4            22
# ..          ...
# 200          28
# 201          25
# 202          23
# 203          27
# 204          25
#
# [205 rows x 13 columns]

# %%
scaler = MinMaxScaler()

# %%
for col in list(num_data.columns):
    num_data[col] = scaler.fit_transform(num_data[[col]])
# Out:
# /tmp/ipykernel_7230/2141124156.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   num_data[col] = scaler.fit_transform(num_data[[col]])
# /tmp/ipykernel_7230/2141124156.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   num_data[col] = scaler.fit_transform(num_data[[col]])
# /tmp/ipykernel_7230/2141124156.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   num_data[col] = scaler.fit_transform(num_data[[col]])
# /tmp/ipykernel_7230/2141124156.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   num_data[col] = scaler.fit_transform(num_data[[col]])
# /tmp/ipykernel_7230/2141124156.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   num_data[col] = scaler.fit_transform(num_data[[col]])
# /tmp/ipykernel_7230/2141124156.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   num_data[col] = scaler.fit_transform(num_data[[col]])
# /tmp/ipykernel_7230/2141124156.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   num_data[col] = scaler.fit_transform(num_data[[col]])
# /tmp/ipykernel_7230/2141124156.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   num_data[col] = scaler.fit_transform(num_data[[col]])
# /tmp/ipykernel_7230/2141124156.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   num_data[col] = scaler.fit_transform(num_data[[col]])
# /tmp/ipykernel_7230/2141124156.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   num_data[col] = scaler.fit_transform(num_data[[col]])
# /tmp/ipykernel_7230/2141124156.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   num_data[col] = scaler.fit_transform(num_data[[col]])
# /tmp/ipykernel_7230/2141124156.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   num_data[col] = scaler.fit_transform(num_data[[col]])
# /tmp/ipykernel_7230/2141124156.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   num_data[col] = scaler.fit_transform(num_data[[col]])

# %%
num_data['wheelbase'].max()
# Out:
# 1.0

# %% [markdown]
# # d) Graphs

# %%
encoded_data[numeric_features] = num_data

# %%
encoded_data
# Out:
#      car_ID  symboling                   CarName  doornumber  carbody  \
# 0         1          3        alfa-romero giulia           2        0
# 1         2          3       alfa-romero stelvio           2        0
# 2         3          1  alfa-romero Quadrifoglio           2        2
# 3         4          2               audi 100 ls           4        3
# 4         5          2                audi 100ls           4        3
# ..      ...        ...                       ...         ...      ...
# 200     201         -1           volvo 145e (sw)           4        3
# 201     202         -1               volvo 144ea           4        3
# 202     203         -1               volvo 244dl           4        3
# 203     204         -1                 volvo 246           4        3
# 204     205         -1               volvo 264gl           4        3
#
#     drivewheel  wheelbase  carlength  carwidth  carheight  ...   peakrpm  \
# 0          rwd   0.058309   0.413433  0.316667   0.083333  ...  0.346939
# 1          rwd   0.058309   0.413433  0.316667   0.083333  ...  0.346939
# 2          rwd   0.230321   0.449254  0.433333   0.383333  ...  0.346939
# 3          fwd   0.384840   0.529851  0.491667   0.541667  ...  0.551020
# 4          4wd   0.373178   0.529851  0.508333   0.541667  ...  0.551020
# ..         ...        ...        ...       ...        ...  ...       ...
# 200        rwd   0.655977   0.711940  0.716667   0.641667  ...  0.510204
# 201        rwd   0.655977   0.711940  0.708333   0.641667  ...  0.469388
# 202        rwd   0.655977   0.711940  0.716667   0.641667  ...  0.551020
# 203        rwd   0.655977   0.711940  0.716667   0.641667  ...  0.265306
# 204        rwd   0.655977   0.711940  0.716667   0.641667  ...  0.510204
#
#       citympg  highwaympg    price  fueltype_diesel  fueltype_gas  \
# 0    0.222222    0.289474  13495.0                0             1
# 1    0.222222    0.289474  16500.0                0             1
# 2    0.166667    0.263158  16500.0                0             1
# 3    0.305556    0.368421  13950.0                0             1
# 4    0.138889    0.157895  17450.0                0             1
# ..        ...         ...      ...              ...           ...
# 200  0.277778    0.315789  16845.0                0             1
# 201  0.166667    0.236842  19045.0                0             1
# 202  0.138889    0.184211  21485.0                0             1
# 203  0.361111    0.289474  22470.0                1             0
# 204  0.166667    0.236842  22625.0                0             1
#
#      aspiration_std  aspiration_turbo  enginelocation_front  \
# 0                 1                 0                     1
# 1                 1                 0                     1
# 2                 1                 0                     1
# 3                 1                 0                     1
# 4                 1                 0                     1
# ..              ...               ...                   ...
# 200               1                 0                     1
# 201               0                 1                     1
# 202               1                 0                     1
# 203               0                 1                     1
# 204               0                 1                     1
#
#      enginelocation_rear
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# ..                   ...
# 200                    0
# 201                    0
# 202                    0
# 203                    0
# 204                    0
#
# [205 rows x 29 columns]

# %%
data[numeric_features] = num_data

# %%
data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# 0          two  convertible        rwd          front   0.058309  ...
# 1          two  convertible        rwd          front   0.058309  ...
# 2          two    hatchback        rwd          front   0.230321  ...
# 3         four        sedan        fwd          front   0.384840  ...
# 4         four        sedan        4wd          front   0.373178  ...
# ..         ...          ...        ...            ...        ...  ...
# 200       four        sedan        rwd          front   0.655977  ...
# 201       four        sedan        rwd          front   0.655977  ...
# 202       four        sedan        rwd          front   0.655977  ...
# 203       four        sedan        rwd          front   0.655977  ...
# 204       four        sedan        rwd          front   0.655977  ...
#
#      enginesize  fuelsystem  boreratio    stroke compressionratio horsepower  \
# 0      0.260377        mpfi   0.664286  0.290476          0.12500   0.262500
# 1      0.260377        mpfi   0.664286  0.290476          0.12500   0.262500
# 2      0.343396        mpfi   0.100000  0.666667          0.12500   0.441667
# 3      0.181132        mpfi   0.464286  0.633333          0.18750   0.225000
# 4      0.283019        mpfi   0.464286  0.633333          0.06250   0.279167
# ..          ...         ...        ...       ...              ...        ...
# 200    0.301887        mpfi   0.885714  0.514286          0.15625   0.275000
# 201    0.301887        mpfi   0.885714  0.514286          0.10625   0.466667
# 202    0.422642        mpfi   0.742857  0.380952          0.11250   0.358333
# 203    0.316981         idi   0.335714  0.633333          1.00000   0.241667
# 204    0.301887        mpfi   0.885714  0.514286          0.15625   0.275000
#
#       peakrpm   citympg  highwaympg    price
# 0    0.346939  0.222222    0.289474  13495.0
# 1    0.346939  0.222222    0.289474  16500.0
# 2    0.346939  0.166667    0.263158  16500.0
# 3    0.551020  0.305556    0.368421  13950.0
# 4    0.551020  0.138889    0.157895  17450.0
# ..        ...       ...         ...      ...
# 200  0.510204  0.277778    0.315789  16845.0
# 201  0.469388  0.166667    0.236842  19045.0
# 202  0.551020  0.138889    0.184211  21485.0
# 203  0.265306  0.361111    0.289474  22470.0
# 204  0.510204  0.166667    0.236842  22625.0
#
# [205 rows x 26 columns]

# %%
data['symboling'] = ["risky" if x in([-3, -2, -1]) else "not_risky" for x in list(data['symboling'])]

# %%
data['symboling']
# Out:
# 0      not_risky
# 1      not_risky
# 2      not_risky
# 3      not_risky
# 4      not_risky
#          ...
# 200        risky
# 201        risky
# 202        risky
# 203        risky
# 204        risky
# Name: symboling, Length: 205, dtype: object

# %%
data.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
with open('./hot_custom_encoded_data.pkl', 'wb') as f:
    pickle.dump(data, f)

# %%
X = data.loc[:, ~data.columns.isin(['car_ID', 'CarName', 'aspiration', 'price'])]

# %%
data['price'] = scaler.fit_transform(data[['price']])

# %%
y = data['price']

# %%
y
# Out:
# 0      0.207959
# 1      0.282558
# 2      0.282558
# 3      0.219254
# 4      0.306142
#          ...
# 200    0.291123
# 201    0.345738
# 202    0.406311
# 203    0.430763
# 204    0.434611
# Name: price, Length: 205, dtype: float64

# %%
fig, axs = plt.subplots(6, 4, figsize=(25, 20))
fig.suptitle('Correlation of Given Variable with Car Price')
cols = list(X.columns)
s = 0
t =0
for i in range(0, len(cols)):
        if t==4:
            s = s+1
            t= 0
        sub = axs[s, t]
        col = cols[i]
        sub.scatter(X[col], y)
        sub.set_xlabel(str(col))
        sub.set_ylabel("Car Price")
        t = t+1

# %%
len(X.columns)
# Out:
# 22

# %%
plt.figure(figsize=(50, 15))
plt.ylabel("Price")
plt.xlabel("Correlated Variables")
plt.legend(cols)
cols = list(X.columns)
for col in cols:
    plt.scatter(X[col], y )

# %%
plt.scatter(X['enginesize'], y)
plt.xlabel("Engine Size")
plt.ylabel("Car Price")
# Out:
# Text(0, 0.5, 'Car Price')

# %%
for col in list(num_data.columns):
    plt.figure()
    plt.scatter(num_data[col], y)
    plt.xlabel(str(col))
    plt.ylabel("Car Price")

# %%
plt.figure(figsize = (25, 15))
leg = ["width", "height", "length"]
plt.scatter(encoded_data['carwidth'],  y)
plt.scatter(encoded_data['carheight'], y)
plt.scatter(encoded_data['carlength'], y)
plt.legend(leg)
plt.xlabel("Correlated Variables")
plt.ylabel("Car Price")
# Out:
# Text(0, 0.5, 'Car Price')
